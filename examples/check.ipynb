# %%
import os
import time
from functools import partial
import pandas as pd
import numpy as np
import xarray as xr
import pickle

# %%
output_dir = os.path.join('/home/rsandhu/zazzle/BSSRS/IpcFusion/examples/csg/output')
FNAME = 'csg_ge_vr.prq_tracks_ca'
fpath = os.path.join(output_dir, 'telemetry', FNAME)
df = pd.read_parquet(fpath)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12975662 entries, 0 to 12975661
# Data columns (total 34 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   TrackTimeElapsed   float32
#  1   PositionX          float32
#  2   PositionX_var      float32
#  3   VelocityX          float32
#  4   VelocityX_var      float32
#  5   AccelerationX      float32
#  6   AccelerationX_var  float32
#  7   TrackID            int16
#  8   PositionY          float32
#  9   PositionY_var      float32
#  10  VelocityY          float32
#  11  VelocityY_var      float32
#  12  AccelerationY      float32
#  13  AccelerationY_var  float32
#  14  Altitude           float32
#  15  Altitude_var       float32
#  16  VelocityVer        float32
#  17  VelocityVer_var    float32
#  18  AccelerationVer    float32
#  19  AccelerationZ_var  float32
#  20  TimeUTC            datetime64[ns]
#  21  TimeLocal          datetime64[ns]
#  22  Group              category
# ...

# %%
df.groupby('Group')['TrackID'].nunique()
# Out:
# /tmp/scratch/9309073/ipykernel_245433/2482101128.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Group')['TrackID'].nunique()
# Group
# hr     282
# pa     607
# wy    7411
# Name: TrackID, dtype: int64

# %%
df.TrackID.max()
# Out:
# np.int16(8300)

# %%
cols = ['Group', 'TrackID','TimeLocal', 'TrackTimeElapsed', 'PositionX', 'PositionY', 'Altitude']
cols+= ['VelocityX', 'VelocityY', 'VelocityVer']
cols+= ['HeadingRateHor','HeadingHor','VelocityHor']
cols+= ['AccelerationX', 'AccelerationY', 'AccelerationVer']
rdf = df[cols].copy()
rdf = rdf[rdf.Group.isin(['pa','wy'])]

# %%
rdf.columns
# Out:
# Index(['Group', 'TrackID', 'TimeLocal', 'TrackTimeElapsed', 'PositionX',
#        'PositionY', 'Altitude', 'VelocityX', 'VelocityY', 'VelocityVer',
#        'HeadingRateHor', 'HeadingHor', 'VelocityHor', 'AccelerationX',
#        'AccelerationY', 'AccelerationVer'],
#       dtype='object')

# %%
rdf.PositionX -= rdf.PositionX.mean()
rdf.PositionY -= rdf.PositionY.mean()

# %%
rdf.to_csv(os.path.join('/home/rsandhu/zazzle/BSSRS/IpcFusion/examples/csg/output/data_for_review.csv'))

# %%
rdf.TrackID.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/scratch/9309073/ipykernel_245433/3129773250.py in ?()
# ----> 1 rdf.TrackID.unique()
#
# ~/.conda-envs/bssrs_env/lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'TrackID'

# %%
rdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12306382 entries, 669280 to 12975661
# Data columns (total 16 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Group             category
#  1   TrackID           int16
#  2   TimeLocal         datetime64[ns]
#  3   TrackTimeElapsed  float32
#  4   PositionX         float32
#  5   PositionY         float32
#  6   Altitude          float32
#  7   VelocityX         float32
#  8   VelocityY         float32
#  9   VelocityVer       float32
#  10  HeadingRateHor    float32
#  11  HeadingHor        float32
#  12  VelocityHor       float32
#  13  AccelerationX     float32
#  14  AccelerationY     float32
#  15  AccelerationVer   float32
# dtypes: category(1), datetime64[ns](1), float32(13), int16(1)
# memory usage: 833.3 MB
